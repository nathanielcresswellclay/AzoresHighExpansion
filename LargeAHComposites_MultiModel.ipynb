# %% [markdown]
# <h1><center>Multimodel Figure</center></h1>

# %% [markdown]
# <b>Since the analysis for each model took a lot of time, I've saved the fields, preprocessed for plotting. They can be loaded by running the cell below. For the code used to to calculate the fields see the end of the notebook</b>

# %%
miroc_lon=xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/miroc.past100.largeAHevents.precip&qtrans.nc')['miroc_lon'].values
miroc_lat=xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/miroc.past100.largeAHevents.precip&qtrans.nc')['miroc_lat'].values
miroc_precip = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/miroc.past100.largeAHevents.precip&qtrans.nc')['miroc_precip'].values
miroc_uq = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/miroc.past100.largeAHevents.precip&qtrans.nc')['miroc_uq'].values
miroc_vq = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/miroc.past100.largeAHevents.precip&qtrans.nc')['miroc_vq'].values
miroc_psl = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/miroc.past100.largeAHevents.psl.nc')['miroc_psl'].values
miroc_lon_centered = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/miroc.past100.largeAHevents.psl.nc')['miroc_lon_centered'].values

bcc_lon=xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/bcc.past100.largeAHevents.precip&qtrans.nc')['bcc_lon'].values
bcc_lat=xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/bcc.past100.largeAHevents.precip&qtrans.nc')['bcc_lat'].values
bcc_precip = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/bcc.past100.largeAHevents.precip&qtrans.nc')['bcc_precip'].values
bcc_uq = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/bcc.past100.largeAHevents.precip&qtrans.nc')['bcc_uq'].values
bcc_vq = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/bcc.past100.largeAHevents.precip&qtrans.nc')['bcc_vq'].values
bcc_psl = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/bcc.past100.largeAHevents.psl.nc')['bcc_psl'].values
bcc_lon_centered = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/bcc.past100.largeAHevents.psl.nc')['bcc_lon_centered'].values

ipsl_lon=xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/ipsl.past100.largeAHevents.precip&qtrans.nc')['ipsl_lon'].values
ipsl_lat=xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/ipsl.past100.largeAHevents.precip&qtrans.nc')['ipsl_lat'].values
ipsl_precip = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/ipsl.past100.largeAHevents.precip&qtrans.nc')['ipsl_precip'].values
ipsl_uq = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/ipsl.past100.largeAHevents.precip&qtrans.nc')['ipsl_uq'].values
ipsl_vq = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/ipsl.past100.largeAHevents.precip&qtrans.nc')['ipsl_vq'].values
ipsl_psl = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/ipsl.past100.largeAHevents.psl.nc')['ipsl_psl'].values
ipsl_lon_centered = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/ipsl.past100.largeAHevents.psl.nc')['ipsl_lon_centered'].values

mpi_lon=xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/mpi.past100.largeAHevents.precip&qtrans.nc')['mpi_lon'].values
mpi_lat=xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/mpi.past100.largeAHevents.precip&qtrans.nc')['mpi_lat'].values
mpi_precip = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/mpi.past100.largeAHevents.precip&qtrans.nc')['mpi_precip'].values
mpi_uq = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/mpi.past100.largeAHevents.precip&qtrans.nc')['mpi_uq'].values
mpi_vq = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/mpi.past100.largeAHevents.precip&qtrans.nc')['mpi_vq'].values
mpi_psl = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/mpi.past100.largeAHevents.psl.nc')['mpi_psl'].values
mpi_lon_centered = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/mpi.past100.largeAHevents.psl.nc')['mpi_lon_centered'].values

giss_lon=xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/giss.past100.largeAHevents.precip&qtrans.nc')['giss_lon'].values
giss_lat=xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/giss.past100.largeAHevents.precip&qtrans.nc')['giss_lat'].values
giss_precip = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/giss.past100.largeAHevents.precip&qtrans.nc')['giss_precip'].values
giss_uq = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/giss.past100.largeAHevents.precip&qtrans.nc')['giss_uq'].values
giss_vq = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/giss.past100.largeAHevents.precip&qtrans.nc')['giss_vq'].values
giss_psl = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/giss.past100.largeAHevents.psl.nc')['giss_psl'].values
giss_lon_centered = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/giss.past100.largeAHevents.psl.nc')['giss_lon_centered'].values

ccsm_lon=xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/ccsm.past100.largeAHevents.precip&qtrans.nc')['ccsm_lon'].values
ccsm_lat=xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/ccsm.past100.largeAHevents.precip&qtrans.nc')['ccsm_lat'].values
ccsm_precip = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/ccsm.past100.largeAHevents.precip&qtrans.nc')['ccsm_precip'].values
ccsm_uq = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/ccsm.past100.largeAHevents.precip&qtrans.nc')['ccsm_uq'].values
ccsm_vq = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/ccsm.past100.largeAHevents.precip&qtrans.nc')['ccsm_vq'].values
ccsm_psl = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/ccsm.past100.largeAHevents.psl.nc')['ccsm_psl'].values
ccsm_lon_centered = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/ccsm.past100.largeAHevents.psl.nc')['ccsm_lon_centered'].values

csiro_lon=xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/csiro.past100.largeAHevents.precip&qtrans.nc')['csiro_lon'].values
csiro_lat=xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/csiro.past100.largeAHevents.precip&qtrans.nc')['csiro_lat'].values
csiro_precip = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/csiro.past100.largeAHevents.precip&qtrans.nc')['csiro_precip'].values
csiro_uq = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/csiro.past100.largeAHevents.precip&qtrans.nc')['csiro_uq'].values
csiro_vq = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/csiro.past100.largeAHevents.precip&qtrans.nc')['csiro_vq'].values
csiro_psl = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/csiro.past100.largeAHevents.psl.nc')['csiro_psl'].values
csiro_lon_centered = xr.open_dataset('/home/ncresswell/Desktop/AzoresHigh_Nature/temp/csiro.past100.largeAHevents.psl.nc')['csiro_lon_centered'].values

# %%
#initialize figure
fig = plt.figure(figsize=(20,40))

rows=5

##############################################         BCC ESM           ##################################################

#q transport and precip during large AH
bcc_precip_qtrans   = get_baseproj(plt.subplot(rows,2,1,projection=ccrs.PlateCarree()),show_lat=True)
add_subplot_index(bcc_precip_qtrans,'a')
bcc_precip_qtrans,_ = plot_precip(ax=bcc_precip_qtrans,lon=bcc_lon,lat=bcc_lat,precip=bcc_precip)
bcc_precip_qtrans,_ = plot_qtrans(ax=bcc_precip_qtrans,lon=bcc_lon,lat=bcc_lat,qu=bcc_uq,qv=bcc_vq)
bcc_precip_qtrans.text(-0.07, 0.55, 'BCC-CSM1.1', va='bottom', ha='center',
                        rotation='vertical', rotation_mode='anchor',
                        transform=bcc_precip_qtrans.transAxes,fontsize=30)
bcc_precip_qtrans.text(0.5, 1.2, 'Precipitation', va='top', ha='center',
                       rotation='horizontal', rotation_mode='anchor',
                       transform=bcc_precip_qtrans.transAxes,fontsize=30)
#q transport and psl during large AH 
bcc_psl_qtrans   = get_baseproj(plt.subplot(rows,2,2,projection=ccrs.PlateCarree()))
add_subplot_index(bcc_psl_qtrans,'b')
bcc_psl_qtrans,_ = plot_psl(ax=bcc_psl_qtrans,lon=bcc_lon_centered,lat=bcc_lat,psl=bcc_psl)
bcc_psl_qtrans,_ = plot_qtrans(ax=bcc_psl_qtrans,lon=bcc_lon,lat=bcc_lat,qu=bcc_uq,qv=bcc_vq)
bcc_psl_qtrans.text(0.5, 1.2, 'Sea Level Pressure', va='top', ha='center',
                    rotation='horizontal', rotation_mode='anchor',
                    transform=bcc_psl_qtrans.transAxes,fontsize=30)


##############################################         CCSM ESM           #################################################

ccsm_precip_qtrans   = get_baseproj(plt.subplot(rows,2,3,projection=ccrs.PlateCarree()),show_lat=True)
add_subplot_index(ccsm_precip_qtrans,'c')
ccsm_precip_qtrans,_ = plot_precip(ax=ccsm_precip_qtrans,lon=ccsm_lon,lat=ccsm_lat,precip=ccsm_precip)
ccsm_precip_qtrans,_ = plot_qtrans(ax=ccsm_precip_qtrans,lon=ccsm_lon,lat=ccsm_lat,qu=ccsm_uq,qv=ccsm_vq,skip=3)
ccsm_precip_qtrans.text(-0.07, 0.55, 'CCSM4', va='bottom', ha='center',
                        rotation='vertical', rotation_mode='anchor',
                        transform=ccsm_precip_qtrans.transAxes,fontsize=30)
#q transport and psl during large AH 
ccsm_psl_qtrans   = get_baseproj(plt.subplot(rows,2,4,projection=ccrs.PlateCarree()))
add_subplot_index(ccsm_psl_qtrans,'d')
ccsm_psl_qtrans,_ = plot_psl(ax=ccsm_psl_qtrans,lon=ccsm_lon_centered,lat=ccsm_lat,psl=ccsm_psl)
ccsm_psl_qtrans,_ = plot_qtrans(ax=ccsm_psl_qtrans,lon=ccsm_lon,lat=ccsm_lat,qu=ccsm_uq,qv=ccsm_vq,skip=3)

##############################################         IPSL ESM           #################################################

ipsl_precip_qtrans   = get_baseproj(plt.subplot(rows,2,5,projection=ccrs.PlateCarree()),show_lat=True)
add_subplot_index(ipsl_precip_qtrans,'e')
ipsl_precip_qtrans,_ = plot_precip(ax=ipsl_precip_qtrans,lon=ipsl_lon,lat=ipsl_lat,precip=ipsl_precip)
ipsl_precip_qtrans,_ = plot_qtrans(ax=ipsl_precip_qtrans,lon=ipsl_lon,lat=ipsl_lat,qu=ipsl_uq,qv=ipsl_vq)
ipsl_precip_qtrans.text(-0.07, 0.55, 'IPSL-CM5A-LR', va='bottom', ha='center',
                        rotation='vertical', rotation_mode='anchor',
                        transform=ipsl_precip_qtrans.transAxes,fontsize=30)
#q transport and psl during large AH 
ipsl_psl_qtrans   = get_baseproj(plt.subplot(rows,2,6,projection=ccrs.PlateCarree()))
add_subplot_index(ipsl_psl_qtrans,'f')
ipsl_psl_qtrans,_ = plot_psl(ax=ipsl_psl_qtrans,lon=ipsl_lon_centered,lat=ipsl_lat,psl=ipsl_psl)
ipsl_psl_qtrans,_ = plot_qtrans(ax=ipsl_psl_qtrans,lon=ipsl_lon,lat=ipsl_lat,qu=ipsl_uq,qv=ipsl_vq)

##############################################        MIROC ESM          ##################################################

#q transport and precip during large AH
miroc_precip_qtrans   = get_baseproj(plt.subplot(rows,2,7,projection=ccrs.PlateCarree()),show_lat=True)
add_subplot_index(miroc_precip_qtrans,'g')
miroc_precip_qtrans,_ = plot_precip(ax=miroc_precip_qtrans,lon=miroc_lon,lat=miroc_lat,precip=miroc_precip)
miroc_precip_qtrans,_ = plot_qtrans(ax=miroc_precip_qtrans,lon=miroc_lon,lat=miroc_lat,qu=miroc_uq,qv=miroc_vq)
miroc_precip_qtrans.text(-0.07, 0.55, 'MIROC-ESM', va='bottom', ha='center',
                        rotation='vertical', rotation_mode='anchor',
                        transform=miroc_precip_qtrans.transAxes,fontsize=30)
#q transport and psl during large AH 
miroc_psl_qtrans   = get_baseproj(plt.subplot(rows,2,8,projection=ccrs.PlateCarree()))
add_subplot_index(miroc_psl_qtrans,'h')
miroc_psl_qtrans,_ = plot_psl(ax=miroc_psl_qtrans,lon=miroc_lon_centered,lat=miroc_lat,psl=miroc_psl)
miroc_psl_qtrans,_ = plot_qtrans(ax=miroc_psl_qtrans,lon=miroc_lon,lat=miroc_lat,qu=miroc_uq,qv=miroc_vq)

##############################################          MPI ESM           #################################################


mpi_precip_qtrans   = get_baseproj(plt.subplot(rows,2,9,projection=ccrs.PlateCarree()),show_lat=True,show_lon=True)
add_subplot_index(mpi_precip_qtrans,'i')
mpi_precip_qtrans,precips = plot_precip(ax=mpi_precip_qtrans,lon=mpi_lon,lat=mpi_lat,precip=mpi_precip)
mpi_precip_qtrans,_ = plot_qtrans(ax=mpi_precip_qtrans,lon=mpi_lon,lat=mpi_lat,qu=mpi_uq,qv=mpi_vq)
mpi_precip_qtrans.text(-0.07, 0.55, 'MPI-ESM-P', va='bottom', ha='center',
                        rotation='vertical', rotation_mode='anchor',
                        transform=mpi_precip_qtrans.transAxes,fontsize=30)
#q transport and psl during large AH 
mpi_psl_qtrans   = get_baseproj(plt.subplot(rows,2,10,projection=ccrs.PlateCarree()),show_lon=True)
add_subplot_index(mpi_psl_qtrans,'j')
mpi_psl_qtrans,pres = plot_psl(ax=mpi_psl_qtrans,lon=mpi_lon_centered,lat=mpi_lat,psl=mpi_psl)
mpi_psl_qtrans,vecs = plot_qtrans(ax=mpi_psl_qtrans,lon=mpi_lon,lat=mpi_lat,qu=mpi_uq,qv=mpi_vq)


#ADD COLORBARS
fig.subplots_adjust(bottom=0.145)
#precip colorbar
precip_cbar_ax = fig.add_axes([0.14, 0.125, 0.33, 0.007])
precip_cbar = fig.colorbar(precips, cax=precip_cbar_ax,orientation='horizontal',ticks=np.arange(-60,63,15))
precip_cbar.ax.tick_params(labelsize=20)
precip_cbar.set_label('mm/month',fontsize=25)
# #psl colorbar
psl_cbar_ax = fig.add_axes([0.565, 0.125, 0.33, 0.007])
psl_cbar = fig.colorbar(pres, cax=psl_cbar_ax,orientation='horizontal',ticks=np.arange(-10,11,2))
psl_cbar.ax.tick_params(labelsize=20)
psl_cbar.set_label('hPa',fontsize=25)

#draw background for quiver key
mpi_psl_qtrans.add_patch(mpatches.Rectangle(xy=[1, 13], width=14, height=13,
                                           facecolor='white',
                                           edgecolor='black',
                                           alpha=1,
                                           transform=ccrs.PlateCarree())
                       )
mpi_psl_qtrans.quiverkey(vecs,X=0.9, Y=.07, U=.01,label='10',fontproperties={'size':35},zorder=12.6);

#Final touchups 
fig.subplots_adjust(wspace=.125,hspace=.0001)

plt.savefig('/home/ncresswell/Desktop/AzoresHigh_Nature/figure_files/revised/LargeAHComposites_Multimodel_REVISED_9-9-21.png',dpi=120)
plt.savefig('/home/ncresswell/Desktop/AzoresHigh_Nature/figure_files/revised/LargeAHComposites_Multimodel_REVISED_9-9-21.pdf',dpi=120)

# %% [markdown]
# <b>Here is the code used to calculate and save each of the fields</b>

# %%
#I wrote this function to make the construction and saving of precip datasets easier. I did this when I had to 
# change the units of the precip files from mm/day to mm/month. It will not work for psl...obviously
def make_dataset_PrecipQtransport(model_name,precip,uq,vq,lon,lat):
    
    temp_xr = xr.Dataset({model_name+'_precip':(['lat','lon'], precip),
                          model_name+'_uq':(['lat','lon'], uq),
                          model_name+'_vq':(['lat','lon'], vq)},
                         coords={model_name+'_lon':(['lon'],lon),
                                 model_name+'_lat':(['lat'],lat),})
    filename = '/home/ncresswell/Desktop/AzoresHigh_Nature/temp/'+model_name+'.past100.largeAHevents.precip&qtrans.nc'
    temp_xr.to_netcdf(filename)

# %% [markdown]
# <center><h3>BCC-ESM</h3></center>

# %%
############################################        Calculate AHA          ################################################
bcc_aha,bcc_psl_djf,bcc_lon_centered = get_aha('/mnt/cmip5-data/CMIP5/output1/BCC/BCC-CSM1.1/past1000/mon/atmos/Amon/r1i1p1/psl/psl_Amon_bcc-csm1-1_past1000_r1i1p1_085001-185012.nc',return_psl=True)

#########################################        Moisture Transport       #################################################
temp_q_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/BCC/BCC-CSM1.1/past1000/mon/atmos/Amon/r1i1p1/hus/hus_Amon_bcc-csm1-1_past1000_r1i1p1_*.nc',
                                  decode_times=False,
                                  decode_cf=False,
                                  concat_dim='time')['hus'].loc[:,85000,:,:][:-1800,:,:]
temp_u_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/BCC/BCC-CSM1.1/past1000/mon/atmos/Amon/r1i1p1/ua/ua_Amon_bcc-csm1-1_past1000_r1i1p1_*.nc',
                                  decode_times=False,
                                  decode_cf=False,
                                  concat_dim='time')['ua'].loc[:,85000,:,:][:-1800,:,:]
temp_v_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/BCC/BCC-CSM1.1/past1000/mon/atmos/Amon/r1i1p1/va/va_Amon_bcc-csm1-1_past1000_r1i1p1_*.nc',
                                  decode_times=False,
                                  decode_cf=False,
                                  concat_dim='time')['va'].loc[:,85000,:,:][:-1800,:,:]
#get seasonal averages and calculate moisture transport
bcc_uq_850hPa_djf = seasonal_averages((temp_q_850hPa*temp_u_850hPa).values,season='DJF')
bcc_vq_850hPa_djf = seasonal_averages((temp_q_850hPa*temp_v_850hPa).values,season='DJF')

############################################        Precipitation         #################################################
temp_precip = xr.open_dataset('/mnt/cmip5-data/CMIP5/output1/BCC/BCC-CSM1.1/past1000/mon/atmos/Amon/r1i1p1/pr/pr_Amon_bcc-csm1-1_past1000_r1i1p1_085001-185012.nc')['pr']
temp_precip_mm_per_month = kgm2s_2_mmm(temp_precip)
#get seasonal averages and convert to mm
bcc_precip_djf = seasonal_averages(temp_precip_mm_per_month,season='DJF')

##############################################  lat and lon for plotting ##################################################
bcc_lat = xr.open_dataset('/mnt/cmip5-data/CMIP5/output1/BCC/BCC-CSM1.1/past1000/mon/atmos/Amon/r1i1p1/psl/psl_Amon_bcc-csm1-1_past1000_r1i1p1_085001-185012.nc',
                              decode_times=False,
                              decode_cf=False)['lat'].values
bcc_lon = xr.open_dataset('/mnt/cmip5-data/CMIP5/output1/BCC/BCC-CSM1.1/past1000/mon/atmos/Amon/r1i1p1/psl/psl_Amon_bcc-csm1-1_past1000_r1i1p1_085001-185012.nc',
                              decode_times=False,
                              decode_cf=False)['lon'].values

# %%
bcc_precip,bcc_uq,bcc_vq,bcc_psl = get_composite_fields(aha          =bcc_aha,
                                                        precip_djf   =bcc_precip_djf,
                                                        uq_850hPa_djf=bcc_uq_850hPa_djf,
                                                        vq_850hPa_djf=bcc_vq_850hPa_djf,
                                                        psl_djf      =bcc_psl_djf)

# %% [markdown]
# <center><h3>CCSM4</h3></center>

# %%
############################################        Calculate AHA          ################################################
ccsm_aha,ccsm_psl_djf,ccsm_lon_centered = get_aha('/mnt/cmip5-data/CMIP5/output1/NCAR/CCSM4/past1000/mon/atmos/Amon/r1i1p1/psl/psl_Amon_CCSM4_past1000_r1i1p1_085001-185012.nc',
                                                  mf_dataset=False,
                                                  return_psl=True)

#########################################        Moisture Transport       #################################################
temp_q_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/NCAR/CCSM4/past1000/mon/atmos/Amon/r1i1p1/hus/hus_Amon_CCSM4_past1000_r1i1p1_*.nc',
                                 decode_times=False,
                                 decode_cf=False,
                                 concat_dim='time')['hus'].loc[:,85000,:,:]
temp_u_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/NCAR/CCSM4/past1000/mon/atmos/Amon/r1i1p1/ua/ua_Amon_CCSM4_past1000_r1i1p1_*.nc',
                                 decode_times=False,
                                 decode_cf=False,
                                 concat_dim='time')['ua'].loc[:,85000,:,:]
temp_v_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/NCAR/CCSM4/past1000/mon/atmos/Amon/r1i1p1/va/va_Amon_CCSM4_past1000_r1i1p1_*.nc',
                                 decode_times=False,
                                 decode_cf=False,
                                 concat_dim='time')['va'].loc[:,85000,:,:]
#get seasonal averages and calculate moisture transport
ccsm_uq_850hPa_djf = seasonal_averages((temp_q_850hPa*temp_u_850hPa).values,season='DJF')
ccsm_vq_850hPa_djf = seasonal_averages((temp_q_850hPa*temp_v_850hPa).values,season='DJF')

############################################        Precipitation         #################################################
temp_precip = xr.open_dataset('/mnt/cmip5-data/CMIP5/output1/NCAR/CCSM4/past1000/mon/atmos/Amon/r1i1p1/pr/pr_Amon_CCSM4_past1000_r1i1p1_085001-185012.nc')['pr']
temp_precip_mm_per_month = kgm2s_2_mmm(temp_precip)
#get seasonal averages and convert to mm
ccsm_precip_djf = seasonal_averages(temp_precip_mm_per_month,season='DJF')

##############################################  lat and lon for plotting ##################################################
ccsm_lat = xr.open_dataset('/mnt/cmip5-data/CMIP5/output1/NCAR/CCSM4/past1000/mon/atmos/Amon/r1i1p1/psl/psl_Amon_CCSM4_past1000_r1i1p1_085001-185012.nc',
                              decode_times=False,
                              decode_cf=False)['lat'].values
ccsm_lon = xr.open_dataset('/mnt/cmip5-data/CMIP5/output1/NCAR/CCSM4/past1000/mon/atmos/Amon/r1i1p1/psl/psl_Amon_CCSM4_past1000_r1i1p1_085001-185012.nc',
                              decode_times=False,
                              decode_cf=False)['lon'].values

# %%
ccsm_precip,ccsm_uq,ccsm_vq,ccsm_psl = get_composite_fields(aha          =ccsm_aha,
                                                            precip_djf   =ccsm_precip_djf,
                                                            uq_850hPa_djf=ccsm_uq_850hPa_djf,
                                                            vq_850hPa_djf=ccsm_vq_850hPa_djf,
                                                            psl_djf      =ccsm_psl_djf)

# %% [markdown]
# <center><h3>IPSL-CM5A-LR</h3></center>

# %%
############################################        Calculate AHA          ################################################
ipsl_aha,ipsl_psl_djf,ipsl_lon_centered = get_aha('/mnt/cmip5-data/CMIP5/output1/IPSL/IPSL-CM5A-LR/past1000/mon/atmos/Amon/r1i1p1/psl/psl_Amon_IPSL-CM5A-LR_past1000_r1i1p1_*.nc',
                                              mf_dataset=True,
                                              return_psl=True)

#########################################        Moisture Transport       #################################################
temp_q_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/IPSL/IPSL-CM5A-LR/past1000/mon/atmos/Amon/r1i1p1/hus/hus_Amon_IPSL-CM5A-LR_past1000_r1i1p1_*.nc',
                                  decode_times=False,
                                  decode_cf=False,
                                  concat_dim='time')['hus'].loc[:,85000,:,:]
temp_u_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/IPSL/IPSL-CM5A-LR/past1000/mon/atmos/Amon/r1i1p1/ua/ua_Amon_IPSL-CM5A-LR_past1000_r1i1p1_*.nc',
                                  decode_times=False,
                                  decode_cf=False,
                                  concat_dim='time')['ua'].loc[:,85000,:,:]
temp_v_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/IPSL/IPSL-CM5A-LR/past1000/mon/atmos/Amon/r1i1p1/va/va_Amon_IPSL-CM5A-LR_past1000_r1i1p1_*.nc',
                                  decode_times=False,
                                  decode_cf=False,
                                  concat_dim='time')['va'].loc[:,85000,:,:]
#get seasonal averages and calculate moisture transport
ipsl_uq_850hPa_djf = seasonal_averages((temp_q_850hPa*temp_u_850hPa).values,season='DJF')
ipsl_vq_850hPa_djf = seasonal_averages((temp_q_850hPa*temp_v_850hPa).values,season='DJF')

############################################        Precipitation         #################################################
temp_precip = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/IPSL/IPSL-CM5A-LR/past1000/mon/atmos/Amon/r1i1p1/pr/pr_Amon_IPSL-CM5A-LR_past1000_r1i1p1_*.nc',
                                  decode_times=False,
                                  decode_cf=False,
                                  concat_dim='time')['pr']
temp_precip_mm_per_month = kgm2s_2_mmm(temp_precip)
#get seasonal averages and convert to mm
ipsl_precip_djf = seasonal_averages(temp_precip_mm_per_month,season='DJF')

##############################################  lat and lon for plotting ##################################################
ipsl_lat = xr.open_dataset('/mnt/cmip5-data/CMIP5/output1/IPSL/IPSL-CM5A-LR/past1000/mon/atmos/Amon/r1i1p1/psl/psl_Amon_IPSL-CM5A-LR_past1000_r1i1p1_085001-104912.nc',
                              decode_times=False,
                              decode_cf=False)['lat'].values
ipsl_lon = xr.open_dataset('/mnt/cmip5-data/CMIP5/output1/IPSL/IPSL-CM5A-LR/past1000/mon/atmos/Amon/r1i1p1/psl/psl_Amon_IPSL-CM5A-LR_past1000_r1i1p1_085001-104912.nc',
                              decode_times=False,
                              decode_cf=False)['lon'].values

# %%
ipsl_precip,ipsl_uq,ipsl_vq,ipsl_psl = get_composite_fields(aha          =ipsl_aha,
                                                            precip_djf   =ipsl_precip_djf,
                                                            uq_850hPa_djf=ipsl_uq_850hPa_djf,
                                                            vq_850hPa_djf=ipsl_vq_850hPa_djf,
                                                            psl_djf      =ipsl_psl_djf)

# %%
make_dataset_PrecipQtransport(model_name='ipsl',
                              precip=ipsl_precip,
                              uq=ipsl_uq,
                              vq=ipsl_vq,
                              lon=ipsl_lon,
                              lat=ipsl_lat)

# %% [markdown]
# <center><h3>MIROC-ESM</h3></center>

# %%
############################################        Calculate AHA          ################################################
miroc_aha,miroc_psl_djf,miroc_lon_centered = get_aha('/mnt/cmip5-data/CMIP5/output1/MIROC/MIROC-ESM/past1000/mon/atmos/Amon/r1i1p1/psl/psl_Amon_MIROC-ESM_past1000_r1i1p1_085001-184912.nc')


#########################################        Moisture Transport       #################################################
temp_q_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/MIROC/MIROC-ESM/past1000/mon/atmos/Amon/r1i1p1/hus/hus_Amon_MIROC-ESM_past1000_r1i1p1_*.nc',
                                  decode_times=False,
                                  decode_cf=False)['hus'].loc[:,85000,:,:]
temp_u_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/MIROC/MIROC-ESM/past1000/mon/atmos/Amon/r1i1p1/ua/ua_Amon_MIROC-ESM_past1000_r1i1p1_*.nc',
                                  decode_times=False,
                                  decode_cf=False)['ua'].loc[:,85000,:,:]
temp_v_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/MIROC/MIROC-ESM/past1000/mon/atmos/Amon/r1i1p1/va/va_Amon_MIROC-ESM_past1000_r1i1p1_*.nc',
                                  decode_times=False,
                                  decode_cf=False)['va'].loc[:,85000,:,:]

#get seasonal averages and calculate moisture transport
miroc_uq_850hPa_djf = seasonal_averages((temp_q_850hPa*temp_u_850hPa).values,season='DJF')
miroc_vq_850hPa_djf = seasonal_averages((temp_q_850hPa*temp_v_850hPa).values,season='DJF')

############################################        Precipitation         #################################################
temp_precip = xr.open_dataset('/mnt/cmip5-data/CMIP5/output1/MIROC/MIROC-ESM/past1000/mon/atmos/Amon/r1i1p1/pr/pr_Amon_MIROC-ESM_past1000_r1i1p1_085001-184912.nc',
                              decode_times=False,
                              decode_cf=False)['pr']
temp_precip_mm_per_month = kgm2s_2_mmm(temp_precip)
#get seasonal averages and convert to mm
miroc_precip_djf = seasonal_averages(temp_precip_mm_per_month,season='DJF')

##############################################  lat and lon for plotting ##################################################
miroc_lat = xr.open_dataset('/mnt/cmip5-data/CMIP5/output1/MIROC/MIROC-ESM/past1000/mon/atmos/Amon/r1i1p1/pr/pr_Amon_MIROC-ESM_past1000_r1i1p1_085001-184912.nc',
                              decode_times=False,
                              decode_cf=False)['lat'].values
miroc_lon = xr.open_dataset('/mnt/cmip5-data/CMIP5/output1/MIROC/MIROC-ESM/past1000/mon/atmos/Amon/r1i1p1/pr/pr_Amon_MIROC-ESM_past1000_r1i1p1_085001-184912.nc',
                              decode_times=False,
                              decode_cf=False)['lon'].values
# Out:
# Loading psl
# Loading q
# Loading u
# Loading v
# calculating q transport
# Loading precip
# Loading lat and lon

# %%
miroc_precip,miroc_uq,miroc_vq,miroc_psl = get_composite_fields(aha=miroc_aha,
                                                                precip_djf=miroc_precip_djf,
                                                                uq_850hPa_djf=miroc_uq_850hPa_djf,
                                                                vq_850hPa_djf=miroc_vq_850hPa_djf,
                                                                psl_djf=miroc_psl_djf)

# %% [markdown]
# <center><h3>MPI-ESM-P</h3></center>

# %%
############################################        Calculate AHA          ################################################
mpi_aha,mpi_psl_djf,mpi_lon_centered = get_aha('/mnt/cmip5-data/CMIP5/output1/MPI-M/MPI-ESM-P/past1000/mon/atmos/Amon/r1i1p1/psl/psl_Amon_MPI-ESM-P_past1000_r1i1p1_085001-184912.nc',
                                               mf_dataset=False,
                                               return_psl=True)

#########################################        Moisture Transport       #################################################
temp_q_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/MPI-M/MPI-ESM-P/past1000/mon/atmos/Amon/r1i1p1/hus/hus_Amon_MPI-ESM-P_past1000_r1i1p1_*.nc',
                                 decode_times=False,
                                 decode_cf=False,
                                 concat_dim='time')['hus'].loc[:,85000,:,:]
temp_u_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/MPI-M/MPI-ESM-P/past1000/mon/atmos/Amon/r1i1p1/ua/ua_Amon_MPI-ESM-P_past1000_r1i1p1_*.nc',
                                 decode_times=False,
                                 decode_cf=False,
                                 concat_dim='time')['ua'].loc[:,85000,:,:]
temp_v_850hPa = xr.open_mfdataset('/mnt/cmip5-data/CMIP5/output1/MPI-M/MPI-ESM-P/past1000/mon/atmos/Amon/r1i1p1/va/va_Amon_MPI-ESM-P_past1000_r1i1p1_*.nc',
                                 decode_times=False,
                                 decode_cf=False,
                                 concat_dim='time')['va'].loc[:,85000,:,:]
#get seasonal averages and calculate moisture transport
mpi_uq_850hPa_djf = seasonal_averages((temp_q_850hPa*temp_u_850hPa).values,season='DJF')
mpi_vq_850hPa_djf = seasonal_averages((temp_q_850hPa*temp_v_850hPa).values,season='DJF')

############################################        Precipitation         #################################################
temp_precip = xr.open_dataset('/mnt/cmip5-data/CMIP5/output1/MPI-M/MPI-ESM-P/past1000/mon/atmos/Amon/r1i1p1/pr/pr_Amon_MPI-ESM-P_past1000_r1i1p1_085001-184912.nc',
                             decode_times=False,
                             decode_cf=False)['pr']
temp_precip_mm_per_month = kgm2s_2_mmm(temp_precip)
#get seasonal averages and convert to mm
mpi_precip_djf = seasonal_averages(temp_precip_mm_per_month,season='DJF')

##############################################  lat and lon for plotting ##################################################
mpi_lat = xr.open_dataset('/mnt/cmip5-data/CMIP5/output1/MPI-M/MPI-ESM-P/past1000/mon/atmos/Amon/r1i1p1/psl/psl_Amon_MPI-ESM-P_past1000_r1i1p1_085001-184912.nc',
                              decode_times=False,
                              decode_cf=False)['lat'].values
mpi_lon = xr.open_dataset('/mnt/cmip5-data/CMIP5/output1/MPI-M/MPI-ESM-P/past1000/mon/atmos/Amon/r1i1p1/psl/psl_Amon_MPI-ESM-P_past1000_r1i1p1_085001-184912.nc',
                              decode_times=False,
                              decode_cf=False)['lon'].values

# %%
mpi_precip,mpi_uq,mpi_vq,mpi_psl = get_composite_fields(aha          =mpi_aha,
                                                        precip_djf   =mpi_precip_djf,
                                                        uq_850hPa_djf=mpi_uq_850hPa_djf,
                                                        vq_850hPa_djf=mpi_vq_850hPa_djf,
                                                        psl_djf      =mpi_psl_djf)

# %%
make_dataset_PrecipQtransport(model_name='mpi',
                              precip=mpi_precip,
                              uq=mpi_uq,
                              vq=mpi_vq,
                              lon=mpi_lon,
                              lat=mpi_lat)

# %%
# %run AzoresHighProjectImports.py
# %run /home/ncresswell/AzoresHighExpansion/MyFunctions/DataAnalyzing.py
# %run /home/ncresswell/AzoresHighExpansion/MyFunctions/DataProcessing.py
# %run /home/ncresswell/AzoresHighExpansion/MyFunctions/Plotting.py

import time
from scipy.interpolate import griddata

def add_subplot_index(ax,index='a',y=.9,x=.03):
    ax.text(x=x,y=y,
            s=index,
            fontsize=30,
            transform=ax.transAxes,fontweight='bold')

def kgm2s_2_mmm(precip):

    precip_data = precip.values*86400 #convert to mm/day

    #january
    precip_data[np.arange(0,precip_data.shape[0],12),:,:]=precip_data[np.arange(0,precip_data.shape[0],12),:,:]*31
    #feb
    precip_data[np.arange(1,precip_data.shape[0],12),:,:]=precip_data[np.arange(1,precip_data.shape[0],12),:,:]*28
    #mar
    precip_data[np.arange(2,precip_data.shape[0],12),:,:]=precip_data[np.arange(2,precip_data.shape[0],12),:,:]*31
    #april
    precip_data[np.arange(3,precip_data.shape[0],12),:,:]=precip_data[np.arange(3,precip_data.shape[0],12),:,:]*30
    #may
    precip_data[np.arange(4,precip_data.shape[0],12),:,:]=precip_data[np.arange(4,precip_data.shape[0],12),:,:]*31
    #june
    precip_data[np.arange(5,precip_data.shape[0],12),:,:]=precip_data[np.arange(5,precip_data.shape[0],12),:,:]*30
    #july
    precip_data[np.arange(6,precip_data.shape[0],12),:,:]=precip_data[np.arange(6,precip_data.shape[0],12),:,:]*31
    #aug
    precip_data[np.arange(7,precip_data.shape[0],12),:,:]=precip_data[np.arange(7,precip_data.shape[0],12),:,:]*31
    #sep
    precip_data[np.arange(8,precip_data.shape[0],12),:,:]=precip_data[np.arange(8,precip_data.shape[0],12),:,:]*30
    #oct
    precip_data[np.arange(9,precip_data.shape[0],12),:,:]=precip_data[np.arange(9,precip_data.shape[0],12),:,:]*31
    #nov
    precip_data[np.arange(10,precip_data.shape[0],12),:,:]=precip_data[np.arange(10,precip_data.shape[0],12),:,:]*30
    #dec
    precip_data[np.arange(11,precip_data.shape[0],12),:,:]=precip_data[np.arange(11,precip_data.shape[0],12),:,:]*31

    return precip_data

"""
This function will plot frequency of extreme events as reported by ERA-20C pressure data over a defined window 

USAGE: to use pass an index that is defined through time, and specify what the threshold is for extreme event using the
      'percent' perameter. 

"""

def running_bin_extremes(index=None, percent=20, window=11, time=np.arange(1850,2006), label_large = '',label_small = '',title = '',legend_loc=2, index_has_nan=False,ylim=None):

    running_bin_big   = np.zeros(index.shape)
    running_bin_small = np.zeros(index_shape)
    
    running_bin_big, running_bin_small = get_bin_timeseries(index=index, percent=percent, window=window)
        
    fig, ax = plt.subplots(figsize=(20,10))

    ax.plot(time,running_bin_big,color='red',linewidth=3,alpha=2,label=label_large);
    ax.plot(time,running_bin_small,color='blue',linewidth=3,alpha=10,label=label_small);
   
    #Alter Ticks and labels
    ax.set_xticklabels(ax.get_xticks().astype(int),fontsize=20)
    ax.set_yticklabels(ax.get_yticks().astype(int),fontsize=20)
    ax.set_ylabel('Number of Extreme Events',fontsize=25)
    
    ax.legend(fontsize=30,loc=legend_loc);
    ax.set_title(title,fontsize=35);
    
    return fig,ax

"""
This function offers the same functionality of the running_bin_extremes_era data but is altered to account for the CESM_LME
meaning it assumed the first dimension of the data is ensemble member number. 

usage: pass index defined along ensemble member and time. observe the default parameters used in the calculation and
       rendering of the plot and change if desired 
"""

def running_bin_extremes_lme(index=None, percent=20, window=11, label_large = '',label_small = '',title = '',legend_loc=2, index_has_nan=False,ylim=None):

    #initialize containers for running bin diagnostic 
    running_bin_big   = np.zeros(index.shape)
    running_bin_small = np.zeros(index.shape)
    
    #iterate through ensemble members
    for e_mem in range(0,13):

        running_bin_big[e_mem,:],running_bin_small[e_mem,:] = get_bin_timeseries(index=index[e_mem,:], 
                                                                                 percent=percent, window=window)

    fig, ax = plt.subplots(figsize=(20,10))
        
    ax.plot(time,running_bin_big.mean(axis=0),color='red',linewidth=3,alpha=2,label=label_large);
    ax.plot(time,running_bin_small.mean(axis=0),color='blue',linewidth=3,alpha=10,label=label_small);
   
    #Alter Ticks and labels
    ax.set_xticklabels(ax.get_xticks().astype(int),fontsize=20)
    ax.set_yticklabels(ax.get_yticks().astype(int),fontsize=20)
    ax.set_ylabel('Number of Extreme Events',fontsize=25)
    
    ax.legend(fontsize=30,loc=legend_loc);
    ax.set_title(title,fontsize=35);
    
    return fig,ax

def get_bin_timeseries(index=None, percent=20, window=11):
    
    running_bin_big   = np.zeros(index.shape)
    running_bin_small = np.zeros(index.shape)
    
    #get list of extreme years
    _,where_largest  = get_extremes(series=index,percent=percent,top=True)
    _,where_smallest = get_extremes(series=index,percent=percent,bot=True)
    
    running_bin_big,_  = extremes_per_window(date_range=np.arange(0,index.size), \
                                                      dates_of_extremes=where_largest, \
                                                      window=window);
    running_bin_small,_= extremes_per_window(date_range=np.arange(0,index.size), \
                                                      dates_of_extremes=where_smallest, \
                                                      window=window);
    
    return running_bin_big, running_bin_small

def get_aha(filename, lon_name='lon',lat_name='lat',var_name='psl',lat_range=[10,52],lon_range=[-60,10],threshold=1021.5,conversion_factor=1/100,mf_dataset = False,return_psl=False,
            detrend = True, trend_region = {'lon_min':-180,'lon_max':180,'lat_min':-90,'lat_max':90}):
    
    #load data
    if mf_dataset:
        psl = xr.open_mfdataset(filename,
                                decode_times=False,
                                decode_cf=False,
                                concat_dim='time')[var_name]
    else:
        psl = xr.open_dataset(filename)[var_name]
    #get seasonal average DJF, also center longitude
    psl_djf,centered_lon = fix_lon(seasonal_averages(psl.values,
                                                     season='DJF')*conversion_factor,
                                   psl[lon_name].values)
    
    if detrend:
        psl_djf = remove_trend_from_region(psl_djf,psl[lat_name],psl[lon_name],trend_region)
        
    #calculate AHA diagnostic
    ah = filter_lat_lon(data_unfiltered=filter_tresh(data_unfiltered=psl_djf,
                                                     below=True,
                                                     threshold=threshold),
                        lat=psl[lat_name].values,
                        lat_range=lat_range,
                        lon=centered_lon,
                        lon_range=lon_range)
    #find AHA
    aha = get_area_of_filtered_data(ah,lat=psl[lat_name].values,
                                    lon=centered_lon)
    if return_psl:
        return aha, psl_djf, centered_lon
    else:
        return aha 

def remove_trend_from_region(psl_djf,lat,lon,trend_region):
    
    dt_data = psl_djf[:,np.logical_and( lat>=trend_region['lat_min'], lat<=trend_region['lat_max']),:]
    dt_data = dt_data[:,:,np.logical_and( lon>=trend_region['lon_min'], lon<=trend_region['lon_max'])] 

    dt_time = np.arange(1850,1850+len(psl_djf))
    dt_timesteps = np.arange(0,dt_time.size)

    trends = np.empty(dt_data.shape[1:])

    #loop through space to get trends 
    for i in range(0,dt_data.shape[1]):
        for j in range(0,dt_data.shape[2]):    
            trends[i,j] = stats.linregress(dt_time,dt_data[:,i,j]).slope

    #create copy of array 
    psl_detrended = psl_djf.copy()

    #calculate geographic weights for later weighted avhc2ging ~~~~ again you must slice one dimension at a time
    weights = np.asarray([np.cos(np.deg2rad(lat))]*lon.shape[0]).transpose()[np.logical_and( lat>=trend_region['lat_min'], lat<=trend_region['lat_max']),:]
    weights = weights[:,np.logical_and( lon>=trend_region['lon_min'], lon<=trend_region['lon_max'])]

    dt_trend = np.average(trends, weights=weights)*dt_timesteps
    
    #loop through PSL and subtract trend_timeseries
    for la in np.where(np.logical_and( lat>trend_region['lat_min'], lat<trend_region['lat_max']))[0]:
        for lo in np.where(np.logical_and( lon>trend_region['lon_min'], lon<trend_region['lon_max']))[0]:

            psl_detrended[:,la,lo] = psl_djf[:,la,lo] - dt_trend

    return psl_detrended 

def get_composite_fields(aha=None,precip_djf=None,uq_850hPa_djf=None,vq_850hPa_djf=None,psl_djf=None,extreme_percent=15):

    ###########################################     FIND EXTREME EVENTS    #########################################
    _,where_largest  = get_extremes(series=aha,percent=extreme_percent,top=True)
    _,where_smallest = get_extremes(series=aha,percent=extreme_percent,bot=True)

    ###########################################     PRECIP ANOMALIES   ##############################################
    precip_largest_anomaly  = precip_djf[where_largest,:,:].mean(axis=0)-precip_djf.mean(axis=0)
    #######################################     U TRANSPORT ANOMALIES   ##########################################
    uq_largest_anomaly  = uq_850hPa_djf[where_largest,:,:].mean(axis=0)-uq_850hPa_djf.mean(axis=0)
    #######################################     V TRANSPORT ANOMALIES   ##########################################
    vq_largest_anomaly  = vq_850hPa_djf[where_largest,:,:].mean(axis=0)-vq_850hPa_djf.mean(axis=0)
    ###########################################     PSL ANOMALIES   ###############################################
    psl_largest_anomaly  = psl_djf[where_largest,:,:].mean(axis=0)-psl_djf.mean(axis=0)
    
    return precip_largest_anomaly,uq_largest_anomaly,vq_largest_anomaly, psl_largest_anomaly

def get_baseproj(ax=None,show_lon=False,show_lat=False):

    ax.set_global()
    ax.set_extent([-65,16,12,60])
    
    #gridlines for references
    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                       linewidth=.5, color='k', linestyle='-',zorder=0)
    gl.xlocator = mticker.FixedLocator(np.arange(-100,40,20))
    gl.ylocator = mticker.FixedLocator(np.arange(-20,81,20))
    
    if show_lon:
        gl.xformatter = LONGITUDE_FORMATTER
        gl.xlabel_style = {'size': 20, 'color': 'k'}
    else:
        gl.xlabels_bottom = False
        
    if show_lat:
        gl.yformatter = LATITUDE_FORMATTER
        gl.ylabel_style = {'size': 20, 'color': 'k'}
    else:
        gl.ylabels_right = False
    
    gl.xlabels_top = False
    gl.ylabels_left = False

    ax.coastlines(linewidth = 1,
                  resolution = '50m',
                  color = 'k',zorder=0);
    
    return ax

def plot_precip(ax=None,lon=None,lat=None,precip=None,conversion=1,add_cp_lon=True):
    
    if add_cp_lon:
        new_precip,new_lon = add_cyclic_point(data=precip,coord=lon)
        im = ax.contourf(new_lon,lat,new_precip*conversion,
                      transform=ccrs.PlateCarree(),
                      extend='both',
                      cmap='BrBG',
                      levels=np.arange(-63,66,6)*conversion,zorder=-1)
    else:
        im = ax.contourf(lon,lat,precip*conversion,
                          transform=ccrs.PlateCarree(),
                          extend='both',
                          cmap='BrBG',
                          levels=np.arange(-63,66,6)*conversion,zorder=-1)
    return ax,im

def plot_psl(ax=None,lon=None,lat=None,psl=None,conversion=1,add_cp_lon=True):
    
    if add_cp_lon:
        new_psl,new_lon = add_cyclic_point(data=psl,coord=lon)
        im = ax.contourf(new_lon,lat,new_psl*conversion,
                         transform=ccrs.PlateCarree(),
                         extend='both',
                         cmap='bwr',
                         levels=np.arange(-11.5,11.6,1),
                         zorder=-1)
    else:
        im = ax.contourf(lon,lat,psl*conversion,
                         transform=ccrs.PlateCarree(),
                         extend='both',
                         cmap='bwr',
                         levels=np.arange(-11.5,11.6,1),
                         zorder=-1)
    return ax,im

def plot_qtrans(ax=None,lon=None,lat=None,qu=None,qv=None,skip=2,legend=False):
    
    vec = ax.quiver(lon[::skip], 
                    lat[::skip], 
                    qu[::skip,::skip], 
                    qv[::skip,::skip], 
                    angles='xy',
                    color="steelblue",
                    scale=.2,
                    width=.003,
                    headwidth=5,
                    transform=ccrs.PlateCarree());
    if legend:
        #draw background for quiver key
        ax.add_patch(mpatches.Rectangle(xy=[-63, 56], width=32, height=8,
                                    facecolor='white',
                                    edgecolor='black',
                                    alpha=1,
                                    transform=ccrs.PlateCarree())
                     )

        ax.quiverkey(qv2,X=0.23, Y=.85, U=.01,label='10 $g*m*kg^{-1}*s^{-1}$',fontproperties={'size':15},zorder=12.6)
    return ax,vec

def get_values(x,y,xs,ys,data):
    return data[np.where(ys==y)[0][0],np.where(xs==x)[0][0]]

def get_interpolated_grid(lon_data=None,lat_data=None,data=None,lon_interp=np.arange(0,360,2),lat_interp = np.arange(-90,90,2)):
    
    #dafine existing fields as points and values 
    points = np.array(np.meshgrid(lat_data,lon_data)).T.reshape(-1,2)
    values = np.empty([points.shape[0]])
    for i in range(0,points.shape[0]):
        values[i] = get_values(points[i,1],points[i,0],lon_data,lat_data,data)

    #perform interpolation with new grid 
    lat_interp_grid,lon_interp_grid = np.meshgrid(lon_interp,lat_interp)
    return griddata(points,values,(lon_interp_grid,lat_interp_grid),method = 'linear')
    
def mm2mmd(precip):

    precip_data = precip.values

    #january
    precip_data[np.arange(0,precip_data.shape[0],12),:,:]=precip_data[np.arange(0,precip_data.shape[0],12),:,:]/31
    #feb
    precip_data[np.arange(1,precip_data.shape[0],12),:,:]=precip_data[np.arange(1,precip_data.shape[0],12),:,:]/28
    #mar
    precip_data[np.arange(2,precip_data.shape[0],12),:,:]=precip_data[np.arange(2,precip_data.shape[0],12),:,:]/31
    #april
    precip_data[np.arange(3,precip_data.shape[0],12),:,:]=precip_data[np.arange(3,precip_data.shape[0],12),:,:]/30
    #may
    precip_data[np.arange(4,precip_data.shape[0],12),:,:]=precip_data[np.arange(4,precip_data.shape[0],12),:,:]/31
    #june
    precip_data[np.arange(5,precip_data.shape[0],12),:,:]=precip_data[np.arange(5,precip_data.shape[0],12),:,:]/30
    #july
    precip_data[np.arange(6,precip_data.shape[0],12),:,:]=precip_data[np.arange(6,precip_data.shape[0],12),:,:]/31
    #aug
    precip_data[np.arange(7,precip_data.shape[0],12),:,:]=precip_data[np.arange(7,precip_data.shape[0],12),:,:]/31
    #sep
    precip_data[np.arange(8,precip_data.shape[0],12),:,:]=precip_data[np.arange(8,precip_data.shape[0],12),:,:]/30
    #oct
    precip_data[np.arange(9,precip_data.shape[0],12),:,:]=precip_data[np.arange(9,precip_data.shape[0],12),:,:]/31
    #nov
    precip_data[np.arange(10,precip_data.shape[0],12),:,:]=precip_data[np.arange(10,precip_data.shape[0],12),:,:]/30
    #dec
    precip_data[np.arange(11,precip_data.shape[0],12),:,:]=precip_data[np.arange(11,precip_data.shape[0],12),:,:]/31

    return precip_data
# Out:
# <style>
# .output {
#     display: flex;
#     align-items: center;
#     text-align: center;
# }
# </style>
